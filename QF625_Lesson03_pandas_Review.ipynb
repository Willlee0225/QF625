# %% [markdown]
# # QF 625 Introduction to Programming
# ## Lesson 03 | An Introduction to `pandas` | `RE`view

# %% [markdown]
# > Let's begin our second meeting of Week 2, Team :) Today, we will learn `pandas`!
#
# > `pandas` is one of the most powerful and popular tools in dealing with data within Python.
#
# > In finance, familiarity with pandas is essential.
#
# > We will work with real-world datasets containing both string and numeric data, often structured around time series.
#
# > You will learn effective data manipulation, analysis, and visualization techniques with pandas.
#
# > First, you will learn
#
# - how to open and read in a csv spreadsheet
# - how to look at the data we have
# - how to select columns
# - how to do some simple math with them

# %%
from IPython.display import Image

# %%
Image("https://www.economist.com/img/b/1000/563/90/sites/default/files/images/print-edition/20160910_CNP002_0.jpg")

# %% [markdown]
# ##### Workflow
# > `import` -> `wrangle` -> `visualize` -> `model` -> `report`
#
# > `Data wrangling` denotes the processes of creating and managing
#
# - (a) `DataFrames`
# - (b) `variables for modeling and visualization`.

# %% [markdown]
# > First we need to `import pandas as a library`. We import the library and then tell Python to refer to it as `pd`. By convention, it's imported as `pd` to save typing.

# %%
import pandas as pd

# %% [markdown]
# ### Reading spreadsheets
#
# > This is how you read a spreadsheet and assign it to an object. Reading in a CSV is just as easy as you'd guess.

# %%
census_data = pd.read_csv("2016_census_data.csv")

# %% [markdown]
# ### Looking at your data
#
# > To look at the data you just read into Python, you can just run a cell with the name of the variable:

# %% [markdown]
# > `A rectangular form of data` = rows (data points; observations; cases) x columns (X, Y variables)
# - `data frame`
# - `data table`
# - `data matrix`
# - `dataset`
#
# $$ y = f(x) $$
#
# - Y as a function of X
# - Y variables: Outcome; Response; Dependent
# - X variables: Predictor: Explanatory; Independent
#
# > Two different types of Modeling
# - Modeling for `Explanation` puts emphasis on X variables
# - Modeling for `Prediction` puts emphasis on Y variables (`Supervised` Machine Learning)

# %%
census_data
# Out:
#             geoid                  name          county          state  \
# 0     34003001000       Census Tract 10   Bergen County     New Jersey
# 1     34003002100       Census Tract 21   Bergen County     New Jersey
# 2     34003002200       Census Tract 22   Bergen County     New Jersey
# 3     34003002300       Census Tract 23   Bergen County     New Jersey
# 4     34003003100       Census Tract 31   Bergen County     New Jersey
# ...           ...                   ...             ...            ...
# 4695  42103950701  Census Tract 9507.01     Pike County   Pennsylvania
# 4696  42103950702  Census Tract 9507.02     Pike County   Pennsylvania
# 4697  42103950801  Census Tract 9508.01     Pike County   Pennsylvania
# 4698  42103950802  Census Tract 9508.02     Pike County   Pennsylvania
# 4699  42103950900     Census Tract 9509     Pike County   Pennsylvania
#
#       total_population  median_income  median_home_value  \
# ...

# %% [markdown]
# > Oops, that's a little long. Maybe we just want to see `the first 10 rows`:

# %%
census_data.head()
# Out:
#          geoid             name          county        state  \
# 0  34003001000  Census Tract 10   Bergen County   New Jersey
# 1  34003002100  Census Tract 21   Bergen County   New Jersey
# 2  34003002200  Census Tract 22   Bergen County   New Jersey
# 3  34003002300  Census Tract 23   Bergen County   New Jersey
# 4  34003003100  Census Tract 31   Bergen County   New Jersey
#
#    total_population  median_income  median_home_value  educational_attainment  \
# 0              6767         151641             680000                    3045
# 1              1522         114545            2000001                     836
# 2              5389          90647             453800                    1791
# 3              5828         112031             610000                    2363
# 4              4946          76906             301900                    1588
#
#    white_alone  black_alone  native  asian  native_hawaiian_pacific_islander  \
# ...

# %% [markdown]
# > Or you might want to look at `the last seven`:

# %%
census_data.tail(7)
# Out:
#             geoid                  name        county          state  \
# 4693  42103950605  Census Tract 9506.05   Pike County   Pennsylvania
# 4694  42103950606  Census Tract 9506.06   Pike County   Pennsylvania
# 4695  42103950701  Census Tract 9507.01   Pike County   Pennsylvania
# 4696  42103950702  Census Tract 9507.02   Pike County   Pennsylvania
# 4697  42103950801  Census Tract 9508.01   Pike County   Pennsylvania
# 4698  42103950802  Census Tract 9508.02   Pike County   Pennsylvania
# 4699  42103950900     Census Tract 9509   Pike County   Pennsylvania
#
#       total_population  median_income  median_home_value  \
# 4693              6056          83220             207100
# 4694              5647          86250             237300
# 4695              4107          61726             155800
# 4696              3119          59239             151100
# 4697              4403          55530             120000
# 4698              6004          50724             146700
# ...

# %% [markdown]
# > or you want to know the `length (the number of observations; data points)` of the entire set:

# %%
len(census_data)
# Out:
# 4700

# %%
census_data.T # T for transpose
# Out:
#                                              0                1     \
# geoid                                 34003001000      34003002100
# name                              Census Tract 10  Census Tract 21
# county                              Bergen County    Bergen County
# state                                  New Jersey       New Jersey
# total_population                             6767             1522
# median_income                              151641           114545
# median_home_value                          680000          2000001
# educational_attainment                       3045              836
# white_alone                                  5667              788
# black_alone                                    75              141
# native                                          0                0
# asian                                         759              444
# native_hawaiian_pacific_islander                0                0
# ...

# %% [markdown]
# ### Filtering by columns (`How to Choose Certain Variables`)
#
# > How about filtering your data by columns? This is how you can do that:

# %%
census_data[["black_alone"]]
# Out:
#       black_alone
# 0              75
# 1             141
# 2              99
# 3              89
# 4             306
# ...           ...
# 4695           12
# 4696           44
# 4697          705
# 4698          970
# 4699           55
#
# [4700 rows x 1 columns]

# %% [markdown]
# > Often, you might want to select `multiple columns`:

# %%
census_data[["black_alone", "native"]]
# Out:
#       black_alone  native
# 0              75       0
# 1             141       0
# 2              99       9
# 3              89      37
# 4             306       0
# ...           ...     ...
# 4695           12       0
# 4696           44       0
# 4697          705       0
# 4698          970      20
# 4699           55      29
#
# [4700 rows x 2 columns]

# %%
column_names=["black_alone", "native"]
a = census_data[column_names]
a
# Out:
#       black_alone  native
# 0              75       0
# 1             141       0
# 2              99       9
# 3              89      37
# 4             306       0
# ...           ...     ...
# 4695           12       0
# 4696           44       0
# 4697          705       0
# 4698          970      20
# 4699           55      29
#
# [4700 rows x 2 columns]

# %%
b = census_data[["black_alone", "native"]]

# %%
a == b
# Out:
#       black_alone  native
# 0            True    True
# 1            True    True
# 2            True    True
# 3            True    True
# 4            True    True
# ...           ...     ...
# 4695         True    True
# 4696         True    True
# 4697         True    True
# 4698         True    True
# 4699         True    True
#
# [4700 rows x 2 columns]

# %% [markdown]
# ### Doing simple math with your data
# > There are a few nifty functions you can apply to your data columns.

# %%
census_data["black_alone"]
# Out:
# 0        75
# 1       141
# 2        99
# 3        89
# 4       306
#        ...
# 4695     12
# 4696     44
# 4697    705
# 4698    970
# 4699     55
# Name: black_alone, Length: 4700, dtype: int64

# %%
a= census_data[["black_alone", "native"]].sum()

# %%
a
# Out:
# black_alone    3155672
# native           61958
# dtype: int64

# %%
census_data["black_alone"].median() # median = robust statistic (scores in samples) vs. (scores in population) paremeters
# Out:
# 198.5

# %%
census_data["black_alone"].mean()
# Out:
# 671.4195744680851

# %%
census_data["black_alone"].std()
# Out:
# 1041.2167909449613

# %% [markdown]
# > There is also this nifty function which gives you a quick overview of your data:

# %%
census_data["black_alone"].describe()
# Out:
# count     4700.000000
# mean       671.419574
# std       1041.216791
# min          0.000000
# 25%         47.000000
# 50%        198.500000
# 75%        889.500000
# max      17123.000000
# Name: black_alone, dtype: float64

# %%
census_data.describe()
# Out:
#               geoid  total_population  median_income  median_home_value  \
# count  4.700000e+03       4700.000000   4.700000e+03       4.700000e+03
# mean   3.546090e+10       4262.009149  -1.269190e+07      -3.983366e+07
# std    1.028020e+09       2031.766771   9.138565e+07       1.589803e+08
# min    3.400300e+10          0.000000  -6.666667e+08      -6.666667e+08
# 25%    3.403118e+10       2865.000000   4.652675e+04       2.914750e+05
# 50%    3.604706e+10       4082.500000   6.894450e+04       4.065000e+05
# 75%    3.608103e+10       5444.000000   9.595675e+04       5.648250e+05
# max    4.210395e+10      29256.000000   2.500010e+05       2.000001e+06
#
#        educational_attainment   white_alone   black_alone       native  \
# count             4700.000000   4700.000000   4700.000000  4700.000000
# mean              1115.373191   2023.984255    671.419574    13.182553
# std                961.185751   1784.767585   1041.216791    34.530966
# ...

# %% [markdown]
# > IQR = Inter-Quartile Range (75th percentile - 25th percentile)
#
# $$ Outliers = 1.5 \times IQR $$

# %% [markdown]
# ### Making new data columns (Add new `variables`)
# > You can make a new column based on two columns like so:

# %%
census_data["black_alone_percentage"] = census_data["black_alone"]/census_data["total_population"]

# %%
census_data["black_alone_percentage"] = census_data["black_alone"]/census_data["total_population"]

# %%
census_data.head()
# Out:
#          geoid             name          county        state  \
# 0  34003001000  Census Tract 10   Bergen County   New Jersey
# 1  34003002100  Census Tract 21   Bergen County   New Jersey
# 2  34003002200  Census Tract 22   Bergen County   New Jersey
# 3  34003002300  Census Tract 23   Bergen County   New Jersey
# 4  34003003100  Census Tract 31   Bergen County   New Jersey
#
#    total_population  median_income  median_home_value  educational_attainment  \
# 0              6767         151641             680000                    3045
# 1              1522         114545            2000001                     836
# 2              5389          90647             453800                    1791
# 3              5828         112031             610000                    2363
# 4              4946          76906             301900                    1588
#
#    white_alone  black_alone  native  asian  native_hawaiian_pacific_islander  \
# ...

# %% [markdown]
# > To overwrite your previous data you can just re-assign the column new values, the way you do with any variable:

# %%
census_data["black_alone_percentage"] = (census_data["black_alone"]/census_data["total_population"])*100

# %%
census_data.tail()
# Out:
#             geoid                  name        county          state  \
# 4695  42103950701  Census Tract 9507.01   Pike County   Pennsylvania
# 4696  42103950702  Census Tract 9507.02   Pike County   Pennsylvania
# 4697  42103950801  Census Tract 9508.01   Pike County   Pennsylvania
# 4698  42103950802  Census Tract 9508.02   Pike County   Pennsylvania
# 4699  42103950900     Census Tract 9509   Pike County   Pennsylvania
#
#       total_population  median_income  median_home_value  \
# 4695              4107          61726             155800
# 4696              3119          59239             151100
# 4697              4403          55530             120000
# 4698              6004          50724             146700
# 4699              4184          49453             146100
#
#       educational_attainment  white_alone  black_alone  native  asian  \
# 4695                     537         3665           12       0     67
# ...

# %% [markdown]
# ##### A quick sorting function can now help you find the spots with the highest or lowest black populations:

# %%
census_data.sort_values(by = "median_income", ascending = False) # sort_values() sorts in ascending order
# Out:
#             geoid              name               county        state  \
# 4532  36119004700   Census Tract 47   Westchester County     New York
# 4595  36119009900   Census Tract 99   Westchester County     New York
# 358   34013020000  Census Tract 200         Essex County   New Jersey
# 359   34013020100  Census Tract 201         Essex County   New Jersey
# 141   34003047300  Census Tract 473        Bergen County   New Jersey
# ...           ...               ...                  ...          ...
# 1994  36047017700  Census Tract 177         Kings County     New York
# 1992  36047017500  Census Tract 175         Kings County     New York
# 2533  36047096000  Census Tract 960         Kings County     New York
# 4017  36085015400  Census Tract 154      Richmond County     New York
# 1974  36047015400  Census Tract 154         Kings County     New York
#
#       total_population  median_income  median_home_value  \
# 4532              3596         250001            2000001
# ...

# %%
census_data.groupby(["county"]).mean()
# Out:
#                             geoid  total_population  median_income  \
# county
#  Bergen County       3.400303e+10       5197.262570   9.666717e+04
#  Bronx County        3.600502e+10       4238.303835  -1.962650e+07
#  Dutchess County     3.602715e+10       3745.632911  -1.680491e+07
#  Essex County        3.401302e+10       3774.219048  -6.285953e+06
#  Hudson County       3.401702e+10       4027.265060  -7.966742e+06
#  Hunterdon County    3.401901e+10       4834.923077   1.091932e+05
#  Kings County        3.604705e+10       3425.561104  -1.133270e+07
#  Middlesex County    3.402300e+10       4753.440000   8.487369e+04
#  Monmouth County     3.402581e+10       4357.861111  -9.169937e+06
#  Morris County       3.402704e+10       4982.150000   1.103502e+05
#  Nassau County       3.605943e+10       4777.468310  -1.867435e+07
#  New York County     3.606101e+10       5677.045139  -2.306436e+07
#  Ocean County        3.402973e+10       4652.111111  -1.580636e+07
# ...

# %% [markdown]
# ### Grouping your data results

# %%
census_data.groupby(["county"])["black_alone_percentage"].mean()
# Out:
# county
#  Bergen County          5.025627
#  Bronx County          28.712968
#  Dutchess County       10.041885
#  Essex County          45.263078
#  Hudson County         11.207193
#  Hunterdon County       2.007026
#  Kings County          30.944145
#  Middlesex County       8.664953
#  Monmouth County        7.739659
#  Morris County          2.998805
#  Nassau County         10.042715
#  New York County       13.612147
#  Ocean County           2.650067
#  Orange County          9.791448
#  Passaic County        12.010305
#  Pike County            4.330738
#  Putnam County          2.341979
#  Queens County         19.101342
#  Richmond County       10.847352
#  Rockland County       10.722122
#  Somerset County        8.283225
#  Suffolk County         6.427984
#  Sussex County          1.915176
#  Union County          21.549694
#  Westchester County    14.935638
# Name: black_alone_percentage, dtype: float64

# %%
census_data
# Out:
#             geoid                  name          county          state  \
# 0     34003001000       Census Tract 10   Bergen County     New Jersey
# 1     34003002100       Census Tract 21   Bergen County     New Jersey
# 2     34003002200       Census Tract 22   Bergen County     New Jersey
# 3     34003002300       Census Tract 23   Bergen County     New Jersey
# 4     34003003100       Census Tract 31   Bergen County     New Jersey
# ...           ...                   ...             ...            ...
# 4695  42103950701  Census Tract 9507.01     Pike County   Pennsylvania
# 4696  42103950702  Census Tract 9507.02     Pike County   Pennsylvania
# 4697  42103950801  Census Tract 9508.01     Pike County   Pennsylvania
# 4698  42103950802  Census Tract 9508.02     Pike County   Pennsylvania
# 4699  42103950900     Census Tract 9509     Pike County   Pennsylvania
#
#       total_population  median_income  median_home_value  \
# ...

# %%
census_data.groupby(["county"])["black_alone_percentage"].mean()
# Out:
# county
#  Bergen County          5.025627
#  Bronx County          28.712968
#  Dutchess County       10.041885
#  Essex County          45.263078
#  Hudson County         11.207193
#  Hunterdon County       2.007026
#  Kings County          30.944145
#  Middlesex County       8.664953
#  Monmouth County        7.739659
#  Morris County          2.998805
#  Nassau County         10.042715
#  New York County       13.612147
#  Ocean County           2.650067
#  Orange County          9.791448
#  Passaic County        12.010305
#  Pike County            4.330738
#  Putnam County          2.341979
#  Queens County         19.101342
#  Richmond County       10.847352
#  Rockland County       10.722122
#  Somerset County        8.283225
#  Suffolk County         6.427984
#  Sussex County          1.915176
#  Union County          21.549694
#  Westchester County    14.935638
# Name: black_alone_percentage, dtype: float64

# %%
census_data.groupby(["county"]).mean()["black_alone_percentage"]
# Out:
# county
#  Bergen County          5.025627
#  Bronx County          28.712968
#  Dutchess County       10.041885
#  Essex County          45.263078
#  Hudson County         11.207193
#  Hunterdon County       2.007026
#  Kings County          30.944145
#  Middlesex County       8.664953
#  Monmouth County        7.739659
#  Morris County          2.998805
#  Nassau County         10.042715
#  New York County       13.612147
#  Ocean County           2.650067
#  Orange County          9.791448
#  Passaic County        12.010305
#  Pike County            4.330738
#  Putnam County          2.341979
#  Queens County         19.101342
#  Richmond County       10.847352
#  Rockland County       10.722122
#  Somerset County        8.283225
#  Suffolk County         6.427984
#  Sussex County          1.915176
#  Union County          21.549694
#  Westchester County    14.935638
# Name: black_alone_percentage, dtype: float64

# %%
import numpy as np

# %%
census_data.groupby(["county"]).agg([np.mean])
# Out:
#                             geoid total_population median_income  \
#                              mean             mean          mean
# county
#  Bergen County       3.400303e+10      5197.262570  9.666717e+04
#  Bronx County        3.600502e+10      4238.303835 -1.962650e+07
#  Dutchess County     3.602715e+10      3745.632911 -1.680491e+07
#  Essex County        3.401302e+10      3774.219048 -6.285953e+06
#  Hudson County       3.401702e+10      4027.265060 -7.966742e+06
#  Hunterdon County    3.401901e+10      4834.923077  1.091932e+05
#  Kings County        3.604705e+10      3425.561104 -1.133270e+07
#  Middlesex County    3.402300e+10      4753.440000  8.487369e+04
#  Monmouth County     3.402581e+10      4357.861111 -9.169937e+06
#  Morris County       3.402704e+10      4982.150000  1.103502e+05
#  Nassau County       3.605943e+10      4777.468310 -1.867435e+07
#  New York County     3.606101e+10      5677.045139 -2.306436e+07
# ...

# %%
census_data.groupby(["county"]).agg({"black_alone_percentage":"mean"})
# Out:
#                      black_alone_percentage
# county
#  Bergen County                     5.025627
#  Bronx County                     28.712968
#  Dutchess County                  10.041885
#  Essex County                     45.263078
#  Hudson County                    11.207193
#  Hunterdon County                  2.007026
#  Kings County                     30.944145
#  Middlesex County                  8.664953
#  Monmouth County                   7.739659
#  Morris County                     2.998805
#  Nassau County                    10.042715
#  New York County                  13.612147
#  Ocean County                      2.650067
#  Orange County                     9.791448
#  Passaic County                   12.010305
#  Pike County                       4.330738
#  Putnam County                     2.341979
#  Queens County                    19.101342
#  Richmond County                  10.847352
#  Rockland County                  10.722122
# ...

# %%
census_data.groupby(["county"]).agg({"total_population": "mean"})
# Out:
#                      total_population
# county
#  Bergen County            5197.262570
#  Bronx County             4238.303835
#  Dutchess County          3745.632911
#  Essex County             3774.219048
#  Hudson County            4027.265060
#  Hunterdon County         4834.923077
#  Kings County             3425.561104
#  Middlesex County         4753.440000
#  Monmouth County          4357.861111
#  Morris County            4982.150000
#  Nassau County            4777.468310
#  New York County          5677.045139
#  Ocean County             4652.111111
#  Orange County            4762.556962
#  Passaic County           5072.040000
#  Pike County              3122.777778
#  Putnam County            5232.000000
#  Queens County            3452.931241
#  Richmond County          4302.945455
#  Rockland County          4963.723077
#  Somerset County          4877.735294
#  Suffolk County           4638.173375
#  Sussex County            3529.121951
# ...

# %%
census_data.groupby(["state"]).agg({"total_population": "sum"})
# Out:
#                total_population
# state
#  New Jersey             6594915
#  New York              13380318
#  Pennsylvania             56210

# %%
census_data.groupby(["state"])["total_population"].sum()
# Out:
# state
#  New Jersey       6594915
#  New York        13380318
#  Pennsylvania       56210
# Name: total_population, dtype: int64

# %%
census_data.dtypes
# Out:
# geoid                                 int64
# name                                 object
# county                               object
# state                                object
# total_population                      int64
# median_income                         int64
# median_home_value                     int64
# educational_attainment                int64
# white_alone                           int64
# black_alone                           int64
# native                                int64
# asian                                 int64
# native_hawaiian_pacific_islander      int64
# some_other_race_alone                 int64
# two_or_more                           int64
# hispanic_or_latino                    int64
# black_alone_percentage              float64
# dtype: object

# %% [markdown]
# ### A Quick Review on `pandas` and `matplotlib`

# %% [markdown]
# > IMPORT

# %%
data = pd.read_csv("countries.csv")
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %% [markdown]
# ##### Let's compare the `population growth rates` between China and the US.

# %% [markdown]
# > You have learned about how to choose columns.
#
# > How would you `choose particular data points`?

# %%
pd.options.display.max_rows = 999

# %%
frequency_table = pd.crosstab(index = data["country"], columns="counts")
frequency_table
# Out:
# col_0                     counts
# country
# Afghanistan                   12
# Albania                       12
# Algeria                       12
# Angola                        12
# Argentina                     12
# Australia                     12
# Austria                       12
# Bahrain                       12
# Bangladesh                    12
# Belgium                       12
# Benin                         12
# Bolivia                       12
# Bosnia and Herzegovina        12
# Botswana                      12
# Brazil                        12
# Bulgaria                      12
# Burkina Faso                  12
# Burundi                       12
# Cambodia                      12
# Cameroon                      12
# Canada                        12
# Central African Republic      12
# Chad                          12
# Chile                         12
# China                         12
# Colombia                      12
# Comoros                       12
# ...

# %%
data.groupby(["country"]).sum()
# Out:
#                            year   population
# country
# Afghanistan               23754    189884585
# Albania                   23754     30962990
# Algeria                   23754    238504874
# Angola                    23754     87712681
# Argentina                 23754    343226879
# Australia                 23754    175791750
# Austria                   23754     90999581
# Bahrain                   23754      4486958
# Bangladesh                23754   1089064744
# Belgium                   23754    116701424
# Benin                     23754     48209960
# Bolivia                   23754     67324742
# Bosnia and Herzegovina    23754     45798297
# Botswana                  23754     11654234
# Brazil                    23754   1467745520
# Bulgaria                  23754     98195824
# Burkina Faso              23754     90584127
# Burundi                   23754     55819300
# Cambodia                  23754    102125168
# Cameroon                  23754    117799781
# ...

# %%
data = data.set_index("country")

# %%
data.loc["Afghanistan"]
# Out:
#              year  population
# country
# Afghanistan  1952     8425333
# Afghanistan  1957     9240934
# Afghanistan  1962    10267083
# Afghanistan  1967    11537966
# Afghanistan  1972    13079460
# Afghanistan  1977    14880372
# Afghanistan  1982    12881816
# Afghanistan  1987    13867957
# Afghanistan  1992    16317921
# Afghanistan  1997    22227415
# Afghanistan  2002    25268405
# Afghanistan  2007    31889923

# %%
china=data.loc["China"]

# %%
china=china.reset_index()
china
# Out:
#    country  year  population
# 0    China  1952   556263527
# 1    China  1957   637408000
# 2    China  1962   665770000
# 3    China  1967   754550000
# 4    China  1972   862030000
# 5    China  1977   943455000
# 6    China  1982  1000281000
# 7    China  1987  1084035000
# 8    China  1992  1164970000
# 9    China  1997  1230075000
# 10   China  2002  1280400000
# 11   China  2007  1318683096

# %% [markdown]
# > WRANGLE

# %%
china = data[data.country == "China"]
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
us = data[data.country == "United States"]
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %% [markdown]
# > VISUALIZE

# %%
import matplotlib.pyplot as plt

# %%
china.population
# Out:
# 288     556263527
# 289     637408000
# 290     665770000
# 291     754550000
# 292     862030000
# 293     943455000
# 294    1000281000
# 295    1084035000
# 296    1164970000
# 297    1230075000
# 298    1280400000
# 299    1318683096
# Name: population, dtype: int64

# %%
plt.plot(china.year, china.population, label = "China", color = "red")
plt.plot(china.year, china.population, "o", color = "red")
plt.plot(us.year, us.population, label = "US", color = "blue")
plt.plot(us.year, us.population, "o", color = "blue")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Population")
plt.show()

# %% [markdown]
# > Well, this is NOT exactly what we wished to have.

# %%
china["new"]=china.population/china.population.iloc[0] * 100
# Out:
# <ipython-input-63-66171f0f8aa8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   china["new"]=china.population/china.population.iloc[0] * 100

# %%
china.population.iloc[0]
# Out:
# 556263527

# %%
plt.plot(china["year"], china.population/china.population.iloc[0] * 100, label = "China", color = "red")
plt.plot(china.year, china.population/china.population.iloc[0] * 100, "o", color = "red")
plt.plot(us.year, us.population/us.population.iloc[0] * 100, label = "US", color = "blue")
plt.plot(us.year, us.population/us.population.iloc[0] * 100, "o", color = "blue")
plt.legend()
plt.title("Population Growth Rate Comparisons between China and the US")
plt.xlabel("Year")
plt.ylabel("Population Growth\n(The First Year in the Data is set at 100)")
plt.show()

# %%
plt.plot(china["year"], china["new"], label = "China", color = "red")
plt.plot(china["year"], china["new"], "o", color = "red")
plt.plot(us.year, us.population/us.population.iloc[0] * 100, label = "US", color = "blue")
plt.plot(us.year, us.population/us.population.iloc[0] * 100, "o", color = "blue")
plt.legend()
plt.title("Population Growth Rate Comparisons between China and the US")
plt.xlabel("Year")
plt.ylabel("Population Growth\n(The First Year in the Data is set at 100)")
plt.show()

# %%
plt.plot(china.year, china.population/china.population.iloc[0] * 100, "o", color = "red")

# %% [markdown]
# > Here's a quick attention checker :) As you could see above, **you might want to add `\n` for creating a new line on y-axis label**.

# %% [markdown]
# `Thank you for working with the script.`

# %%
exit()
